# %% [markdown]
# # Solar Power Forecasting Using Vector Auto Regression

# %% [markdown]
# 1. Read labeled data from output.xlsx
# 2. Set forecast_days
# 3. Generate probabilistic labels
# 4. Run VAR

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
forecast_days = 7

# %%
xls = pd.ExcelFile("output.xlsx")

# %%
years = ["2012","2013","2014","2015","2016","2017","2018","2019","2020"]

# %%
df_obj = dict()
for i in years:
    df_obj[i] = pd.read_excel(xls, i)
    df_obj[i] = df_obj[i].drop(["Unnamed: 0"],axis=True)

# %% [markdown]
# ## Forecasting start

# %%
df = df_obj['2015']
# df = df.append(df_obj['2016'])
for i in range(2016,2019):
    df = df.append(df_obj[str(i)])
    
df1 = df.drop(["1104500527", "1104500529", "1.104501e+09", "7802195.0", "2100570073/ 2100567820/ 2100567898", 
                    "Aggregate Meter Reading (KWH)", 
                    "Difference", "SEEDs data (KWH)", "Insolation", 
                    "PR (%)", "Any Issues/Problems Observed", "WO#", "NO-OFF-CLEAN MODULES"], axis=1)

# %%
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1 = df1.set_index('Date')

# %%
for i in df1.columns[1:]:
    print(i)
    temp = df1[i].value_counts().to_dict()
    print(temp)
    if 1.0 in temp.keys():
        df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# Out:
# Grid Failure
# {0: 919, 1: 542}
# Inverter
# {0: 1298, 1: 163}
# Module Cleaning
# {1: 797, 0: 664}
# Rainy day
# {0: 1417, 1: 44}
# No Module Cleaning
# {0: 1375, 1: 86}
# Transformer replacement and maintenance
# {0: 1443, 1: 18}
# Cable and Fuse maintenance
# {0: 1410, 1: 51}
# Plant Shutdown
# {0: 1460, 1: 1}
# Internet
# {0: 1458, 1: 3}
# Battery
# {0: 1460, 1: 1}
# Cloudy
# {0: 1104, 1: 357}
# Module Cleaning by rains
# {0: 1461}
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100
# /var/folders/4r/3pd1tn_x59n48w85hg2nw0zm0000gn/T/ipykernel_16041/3228102123.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[str(i)][df1[str(i)] == 1.0] = temp[1.0]/100

# %%
df1.head()
# Out:
#             Total Generation (KWH)  Grid Failure  Inverter  Module Cleaning  \
# Date
# 2015-01-01                 2162.50          0.00       0.0              0.0
# 2015-01-02                 3322.93          5.42       0.0              0.0
# 2006-01-03                 3908.96          5.42       0.0              0.0
# 2015-01-04                 4394.29          5.42       0.0              0.0
# 2015-01-05                 3719.55          0.00       0.0              0.0
#
#             Rainy day  No Module Cleaning  \
# Date
# 2015-01-01        0.0                 0.0
# 2015-01-02        0.0                 0.0
# 2006-01-03        0.0                 0.0
# 2015-01-04        0.0                 0.0
# 2015-01-05        0.0                 0.0
#
#             Transformer replacement and maintenance  \
# Date
# 2015-01-01                                      0.0
# 2015-01-02                                      0.0
# 2006-01-03                                      0.0
# 2015-01-04                                      0.0
# 2015-01-05                                      0.0
#
#             Cable and Fuse maintenance  Plant Shutdown  Internet  Battery  \
# Date
# 2015-01-01                        0.51             0.0       0.0      0.0
# 2015-01-02                        0.00             0.0       0.0      0.0
# 2006-01-03                        0.00             0.0       0.0      0.0
# 2015-01-04                        0.00             0.0       0.0      0.0
# 2015-01-05                        0.00             0.0       0.0      0.0
#
#             Cloudy  Module Cleaning by rains
# Date
# 2015-01-01     0.0                         0
# 2015-01-02     0.0                         0
# 2006-01-03     0.0                         0
# 2015-01-04     0.0                         0
# 2015-01-05     0.0                         0

# %%
df1['Total Generation (KWH)'] = pd.to_numeric(df1['Total Generation (KWH)'])
df1['Total Generation (KWH)'].dtype
# Out:
# dtype('float64')

# %%
corr_df = df1.corr()
# corr_df[corr_df < 0] = 0
corr_df
# Out:
#                                          Total Generation (KWH)  Grid Failure  \
# Total Generation (KWH)                                 1.000000     -0.133468
# Grid Failure                                          -0.133468      1.000000
# Inverter                                              -0.323207      0.060894
# Module Cleaning                                        0.364424      0.023704
# Rainy day                                             -0.294625      0.005612
# No Module Cleaning                                     0.030057     -0.095742
# Transformer replacement and maintenance               -0.049581     -0.008704
# Cable and Fuse maintenance                             0.066438     -0.007101
# Plant Shutdown                                         0.022972      0.034079
# Internet                                               0.012075     -0.034836
# Battery                                                0.019410     -0.020099
# Cloudy                                                -0.498287     -0.031126
# Module Cleaning by rains                                    NaN           NaN
#
#                                          Inverter  Module Cleaning  Rainy day  \
# Total Generation (KWH)                  -0.323207         0.364424  -0.294625
# Grid Failure                             0.060894         0.023704   0.005612
# Inverter                                 1.000000        -0.388241   0.420938
# Module Cleaning                         -0.388241         1.000000  -0.193057
# Rainy day                                0.420938        -0.193057   1.000000
# No Module Cleaning                      -0.088625        -0.273995  -0.044070
# Transformer replacement and maintenance  0.039255         0.014713   0.016624
# Cable and Fuse maintenance              -0.067396         0.008827  -0.011694
# Plant Shutdown                          -0.009274         0.023888  -0.004612
# Internet                                -0.016075         0.011037  -0.007993
# Battery                                 -0.009274        -0.028673  -0.004612
# Cloudy                                   0.233595        -0.469456   0.309879
# Module Cleaning by rains                      NaN              NaN        NaN
#
#                                          No Module Cleaning  \
# Total Generation (KWH)                             0.030057
# Grid Failure                                      -0.095742
# Inverter                                          -0.088625
# Module Cleaning                                   -0.273995
# Rainy day                                         -0.044070
# No Module Cleaning                                 1.000000
# Transformer replacement and maintenance           -0.027932
# Cable and Fuse maintenance                        -0.000033
# Plant Shutdown                                    -0.006545
# Internet                                          -0.011344
# Battery                                           -0.006545
# Cloudy                                            -0.006865
# Module Cleaning by rains                                NaN
#
#                                          Transformer replacement and maintenance  \
# Total Generation (KWH)                                                 -0.049581
# Grid Failure                                                           -0.008704
# Inverter                                                                0.039255
# Module Cleaning                                                         0.014713
# Rainy day                                                               0.016624
# No Module Cleaning                                                     -0.027932
# Transformer replacement and maintenance                                 1.000000
# Cable and Fuse maintenance                                             -0.021241
# Plant Shutdown                                                         -0.002923
# Internet                                                               -0.005066
# Battery                                                                -0.002923
# Cloudy                                                                 -0.049072
# Module Cleaning by rains                                                     NaN
#
#                                          Cable and Fuse maintenance  \
# Total Generation (KWH)                                     0.066438
# Grid Failure                                              -0.007101
# Inverter                                                  -0.067396
# Module Cleaning                                            0.008827
# Rainy day                                                 -0.011694
# No Module Cleaning                                        -0.000033
# Transformer replacement and maintenance                   -0.021241
# Cable and Fuse maintenance                                 1.000000
# Plant Shutdown                                            -0.004977
# Internet                                                  -0.008627
# Battery                                                   -0.004977
# Cloudy                                                    -0.047401
# Module Cleaning by rains                                        NaN
#
#                                          Plant Shutdown  Internet   Battery  \
# Total Generation (KWH)                         0.022972  0.012075  0.019410
# Grid Failure                                   0.034079 -0.034836 -0.020099
# Inverter                                      -0.009274 -0.016075 -0.009274
# Module Cleaning                                0.023888  0.011037 -0.028673
# Rainy day                                     -0.004612 -0.007993 -0.004612
# No Module Cleaning                            -0.006545 -0.011344 -0.006545
# Transformer replacement and maintenance       -0.002923 -0.005066 -0.002923
# Cable and Fuse maintenance                    -0.004977 -0.008627 -0.004977
# Plant Shutdown                                 1.000000 -0.001187 -0.000685
# Internet                                      -0.001187  1.000000 -0.001187
# Battery                                       -0.000685 -0.001187  1.000000
# Cloudy                                        -0.014882 -0.025795 -0.014882
# Module Cleaning by rains                            NaN       NaN       NaN
#
#                                            Cloudy  Module Cleaning by rains
# Total Generation (KWH)                  -0.498287                       NaN
# Grid Failure                            -0.031126                       NaN
# Inverter                                 0.233595                       NaN
# Module Cleaning                         -0.469456                       NaN
# Rainy day                                0.309879                       NaN
# No Module Cleaning                      -0.006865                       NaN
# Transformer replacement and maintenance -0.049072                       NaN
# Cable and Fuse maintenance              -0.047401                       NaN
# Plant Shutdown                          -0.014882                       NaN
# Internet                                -0.025795                       NaN
# Battery                                 -0.014882                       NaN
# Cloudy                                   1.000000                       NaN
# Module Cleaning by rains                      NaN                       NaN

# %%
for i in df1.columns[1:]:
    print(df1[i].value_counts())
# Out:
# 0.00    919
# 5.42    542
# Name: Grid Failure, dtype: int64
# 0.00    1298
# 1.63     163
# Name: Inverter, dtype: int64
# 7.97    797
# 0.00    664
# Name: Module Cleaning, dtype: int64
# 0.00    1417
# 0.44      44
# Name: Rainy day, dtype: int64
# 0.00    1375
# 0.86      86
# Name: No Module Cleaning, dtype: int64
# 0.00    1443
# 0.18      18
# Name: Transformer replacement and maintenance, dtype: int64
# 0.00    1410
# 0.51      51
# Name: Cable and Fuse maintenance, dtype: int64
# 0.00    1460
# 0.01       1
# Name: Plant Shutdown, dtype: int64
# 0.00    1458
# 0.03       3
# Name: Internet, dtype: int64
# 0.00    1460
# 0.01       1
# Name: Battery, dtype: int64
# 0.00    1104
# 3.57     357
# Name: Cloudy, dtype: int64
# 0    1461
# Name: Module Cleaning by rains, dtype: int64

# %%
df1 = df1.drop(["Cable and Fuse maintenance","No Module Cleaning","Inverter","Rainy day","Transformer replacement and maintenance","Plant Shutdown","Internet","Battery","Module Cleaning by rains"], axis=1)
df1
# Out:
#             Total Generation (KWH)  Grid Failure  Module Cleaning  Cloudy
# Date
# 2015-01-01                 2162.50          0.00             0.00     0.0
# 2015-01-02                 3322.93          5.42             0.00     0.0
# 2006-01-03                 3908.96          5.42             0.00     0.0
# 2015-01-04                 4394.29          5.42             0.00     0.0
# 2015-01-05                 3719.55          0.00             0.00     0.0
# ...                            ...           ...              ...     ...
# 2018-12-27                 4129.29          5.42             7.97     0.0
# 2018-12-28                 4266.50          0.00             7.97     0.0
# 2018-12-29                 3732.03          5.42             7.97     0.0
# 2018-12-30                 4063.88          0.00             0.00     0.0
# 2018-12-31                 4093.90          5.42             7.97     0.0
#
# [1461 rows x 4 columns]

# %%
endog_array = df1.to_numpy(dtype=int)

# %%
var_model = VAR(endog_array)

# %%
var_model.select_order(48).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results = var_model.fit(15)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 21, Jan, 2022
# Time:                     19:14:11
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    16.3726
# Nobs:                     1446.00    HQIC:                   15.8145
# Log likelihood:          -19156.8    FPE:                5.29563e+06
# AIC:                      15.4822    Det(Omega_mle):     4.48888e+06
# --------------------------------------------------------------------
# Results for equation y1
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
#
# L13.y3        -0.003099         0.026875           -0.115           0.908
# L13.y4        -0.055203         0.130345           -0.424           0.672
# L14.y1        -0.000156         0.000109           -1.426           0.154
# L14.y2         0.047944         0.027300            1.756           0.079
# L14.y3         0.019933         0.026752            0.745           0.456
# L14.y4        -0.039592         0.130060           -0.304           0.761
# L15.y1         0.000207         0.000097            2.132           0.033
# L15.y2         0.062809         0.027124            2.316           0.021
# L15.y3        -0.005894         0.025865           -0.228           0.820
# L15.y4         0.149876         0.113194            1.324           0.185
# =========================================================================
#
# Results for equation y3
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const          0.349148         0.471605            0.740           0.459
# L1.y1          0.000292         0.000098            2.988           0.003
# L1.y2         -0.020964         0.027860           -0.752           0.452
# L1.y3          0.334999         0.026737           12.529           0.000
# L1.y4         -0.301313         0.117098           -2.573           0.010
# L2.y1          0.000319         0.000111            2.870           0.004
# L2.y2          0.052395         0.028110            1.864           0.062
# L2.y3          0.050594         0.027289            1.854           0.064
# L2.y4          0.116583         0.133847            0.871           0.384
# L3.y1         -0.000129         0.000112           -1.159           0.246
# L3.y2          0.007197         0.028197            0.255           0.799
# L3.y3          0.086592         0.027251            3.178           0.001
# L3.y4         -0.262717         0.134015           -1.960           0.050
# L4.y1          0.000036         0.000112            0.325           0.745
# L4.y2          0.044930         0.028167            1.595           0.111
# L4.y3         -0.034668         0.027443           -1.263           0.206
# L4.y4          0.188102         0.135605            1.387           0.165
# L5.y1          0.000148         0.000112            1.321           0.186
# L5.y2          0.037048         0.028139            1.317           0.188
# L5.y3          0.003873         0.027480            0.141           0.888
# L5.y4         -0.046910         0.135673           -0.346           0.730
# L6.y1         -0.000093         0.000112           -0.830           0.407
# L6.y2          0.032019         0.028042            1.142           0.254
# L6.y3         -0.002774         0.027424           -0.101           0.919
# L6.y4          0.019920         0.135513            0.147           0.883
# L7.y1         -0.000040         0.000112           -0.354           0.723
# L7.y2         -0.008390         0.028015           -0.299           0.765
# L7.y3          0.334501         0.027356           12.228           0.000
# L7.y4         -0.233692         0.135756           -1.721           0.085
# L8.y1         -0.000081         0.000112           -0.725           0.468
# L8.y2         -0.015313         0.027972           -0.547           0.584
# L8.y3         -0.127998         0.028517           -4.489           0.000
# L8.y4          0.022996         0.135405            0.170           0.865
# L9.y1         -0.000204         0.000112           -1.819           0.069
# L9.y2          0.003048         0.027949            0.109           0.913
# L9.y3         -0.026167         0.027438           -0.954           0.340
# L9.y4          0.131655         0.135012            0.975           0.329
# L10.y1         0.000075         0.000112            0.671           0.502
# L10.y2        -0.000488         0.027927           -0.017           0.986
# L10.y3        -0.067593         0.027449           -2.462           0.014
# L10.y4         0.200939         0.134934            1.489           0.136
# L11.y1         0.000026         0.000112            0.230           0.818
# L11.y2         0.020621         0.027947            0.738           0.461
# L11.y3         0.028731         0.027559            1.043           0.297
# L11.y4         0.016015         0.134443            0.119           0.905
# L12.y1        -0.000083         0.000112           -0.745           0.456
# L12.y2         0.018178         0.027859            0.653           0.514
# L12.y3         0.008642         0.027532            0.314           0.754
# L12.y4         0.145505         0.134247            1.084           0.278
# L13.y1         0.000049         0.000112            0.439           0.660
# L13.y2         0.010609         0.027838            0.381           0.703
# L13.y3        -0.060425         0.027389           -2.206           0.027
# L13.y4        -0.228237         0.132839           -1.718           0.086
# L14.y1        -0.000068         0.000112           -0.608           0.543
# L14.y2         0.004620         0.027823            0.166           0.868
# L14.y3         0.273186         0.027264           10.020           0.000
# L14.y4         0.160611         0.132549            1.212           0.226
# L15.y1         0.000067         0.000099            0.671           0.502
# L15.y2        -0.054521         0.027643           -1.972           0.049
# L15.y3        -0.189520         0.026360           -7.190           0.000
# L15.y4        -0.306369         0.115361           -2.656           0.008
# =========================================================================
#
# Results for equation y4
# =========================================================================
#             coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------
# const          0.145466         0.111229            1.308           0.191
# L1.y1         -0.000060         0.000023           -2.587           0.010
# L1.y2         -0.007592         0.006571           -1.155           0.248
# L1.y3          0.001943         0.006306            0.308           0.758
# L1.y4          0.597451         0.027618           21.633           0.000
# L2.y1          0.000019         0.000026            0.735           0.463
# L2.y2          0.008183         0.006630            1.234           0.217
# L2.y3          0.000986         0.006436            0.153           0.878
# L2.y4          0.081785         0.031568            2.591           0.010
# L3.y1         -0.000007         0.000026           -0.272           0.786
# L3.y2          0.001618         0.006650            0.243           0.808
# L3.y3          0.011370         0.006427            1.769           0.077
# L3.y4          0.155325         0.031608            4.914           0.000
# L4.y1          0.000065         0.000026            2.483           0.013
# L4.y2          0.000682         0.006643            0.103           0.918
# L4.y3         -0.005088         0.006472           -0.786           0.432
# L4.y4         -0.003031         0.031983           -0.095           0.924
# L5.y1         -0.000089         0.000026           -3.385           0.001
# L5.y2          0.000906         0.006637            0.136           0.891
# L5.y3         -0.011033         0.006481           -1.702           0.089
# L5.y4          0.015483         0.031999            0.484           0.628
# L6.y1          0.000051         0.000026            1.913           0.056
# L6.y2         -0.003264         0.006614           -0.494           0.622
# L6.y3         -0.002971         0.006468           -0.459           0.646
# L6.y4          0.029233         0.031961            0.915           0.360
# L7.y1         -0.000012         0.000026           -0.442           0.659
# L7.y2         -0.002741         0.006607           -0.415           0.678
# L7.y3          0.004094         0.006452            0.635           0.526
# L7.y4          0.017427         0.032018            0.544           0.586
# L8.y1          0.000012         0.000026            0.438           0.661
# L8.y2          0.008783         0.006597            1.331           0.183
# L8.y3         -0.017082         0.006726           -2.540           0.011
# L8.y4         -0.035452         0.031935           -1.110           0.267
# L9.y1          0.000015         0.000026            0.560           0.576
# L9.y2         -0.001396         0.006592           -0.212           0.832
# L9.y3         -0.002588         0.006471           -0.400           0.689
# L9.y4          0.008849         0.031843            0.278           0.781
# L10.y1         0.000010         0.000026            0.370           0.711
# L10.y2        -0.005760         0.006587           -0.875           0.382
# L10.y3        -0.003694         0.006474           -0.571           0.568
# L10.y4        -0.009935         0.031824           -0.312           0.755
# L11.y1         0.000003         0.000026            0.110           0.913
# L11.y2         0.007032         0.006591            1.067           0.286
# L11.y3         0.005897         0.006500            0.907           0.364
# L11.y4        -0.010735         0.031709           -0.339           0.735
# L12.y1         0.000018         0.000026            0.683           0.494
# L12.y2         0.001981         0.006571            0.301           0.763
# L12.y3         0.004694         0.006494            0.723           0.470
# L12.y4        -0.020130         0.031662           -0.636           0.525
# L13.y1        -0.000006         0.000026           -0.229           0.819
# L13.y2        -0.005681         0.006566           -0.865           0.387
# L13.y3         0.002099         0.006460            0.325           0.745
# L13.y4         0.044205         0.031330            1.411           0.158
# L14.y1        -0.000042         0.000026           -1.602           0.109
# L14.y2        -0.002033         0.006562           -0.310           0.757
# L14.y3        -0.000927         0.006430           -0.144           0.885
# L14.y4         0.065267         0.031262            2.088           0.037
# L15.y1        -0.000001         0.000023           -0.055           0.956
# L15.y2         0.008956         0.006520            1.374           0.170
# L15.y3         0.006391         0.006217            1.028           0.304
# L15.y4         0.001779         0.027208            0.065           0.948
# =========================================================================
#
# Correlation matrix of residuals
#             y1        y2        y3        y4
# y1    1.000000 -0.182924  0.065041 -0.188112
# y2   -0.182924  1.000000  0.035654 -0.027668
# y3    0.065041  0.035654  1.000000 -0.166065
# y4   -0.188112 -0.027668 -0.166065  1.000000

# %%
lag = results.k_ar

# %%
forecast_results = results.forecast(df1.values[-lag:],steps=forecast_days)

# %% [markdown]
# ## Results

# %%
forecast_power = []
grid_pred = []
module_pred = []
cloudy_pred = []
for i in forecast_results:
    forecast_power.append(i[0])
    grid_pred.append(i[1])
    module_pred.append(i[2])
    cloudy_pred.append(i[3])

# %%
power_16 = df_obj['2019']['Total Generation (KWH)']
diff_power = pd.DataFrame({"prediction":forecast_power[:forecast_days],"Original":power_16[:forecast_days],
                           "Grid_pred":grid_pred[:forecast_days],
                          "Module_pred":module_pred[:forecast_days],"Cloudy_pred":cloudy_pred[:forecast_days]})
diff_power['Difference'] = diff_power['prediction'] - diff_power['Original']
diff_power
# Out:
#     prediction  Original  Grid_pred  Module_pred  Cloudy_pred  Difference
# 0  4018.640651   3812.94   2.288584     6.623224     0.018846  205.700651
# 1  4036.375953   3920.74   2.563440     6.999218    -0.082425  115.635953
# 2  4149.373292   4113.45   1.988006     6.567682    -0.056345   35.923292
# 3  4034.114846   3873.59   2.543074     6.511389     0.008998  160.524846
# 4  3948.197355   3603.61   2.798425     6.768438    -0.018902  344.587355
# 5  3944.778979   4401.37   2.495622     1.124643    -0.015308 -456.591021
# 6  3796.379330   3852.56   2.932139     6.863326     0.176064  -56.180670

# %% [markdown]
# ## Plot results

# %%
diff_power.plot()
# Out:
# <AxesSubplot:>

# %%
mean_squared_error(power_16[:forecast_days],forecast_power)**(1/2)
# Out:
# 242.93303433065952

# %%
mean_absolute_error(power_16[:forecast_days],forecast_power)
# Out:
# 196.44911258594357
